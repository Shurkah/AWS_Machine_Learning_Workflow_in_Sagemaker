# %% [markdown]
# # Deploy and monitor a machine learning workflow for Image Classification

# %% [markdown]
# ## Setting up this notebook
#
# Notes about the instance size and kernel setup: this notebook has been tested on
#
# 1. The `Python 3 (Data Science)` kernel
# 2. The `ml.t3.medium` Sagemaker notebook instance
#
# ## Data Staging
#
# We'll use a sample dataset called CIFAR to simulate the challenges Scones Unlimited are facing in Image Classification. In order to start working with CIFAR we'll need to:
#
# 1. Extract the data from a hosting service
# 2. Transform it into a usable shape and format
# 3. Load it into a production system
#
# In other words, we're going to do some simple ETL!
#
# ### 1. Extract the data from the hosting service
#
# In the cell below, define a function `extract_cifar_data` that extracts python version of the CIFAR-100 dataset. The CIFAR dataaset is open source and generously hosted by the University of Toronto at: https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz

# %%
import requests

def extract_cifar_data(url, filename="cifar.tar.gz"):
    """A function for extracting the CIFAR-100 dataset and storing it as a gzipped file
    
    Arguments:
    url      -- the URL where the dataset is hosted
    filename -- the full path where the dataset will be written
    
    """
    
    r = requests.get(url)
    with open(filename, "wb") as file_context:
        file_context.write(r.content)
    return

# %% [markdown]
# Let's test it out! Run the following cell and check whether a new file `cifar.tar.gz` is created in the file explorer.

# %%
extract_cifar_data("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz")

# %% [markdown]
# ### 2. Transform the data into a usable shape and format
#
# Clearly, distributing the data as a gzipped archive makes sense for the hosting service! It saves on bandwidth, storage, and it's a widely-used archive format. In fact, it's so widely used that the Python community ships a utility for working with them, `tarfile`, as part of its Standard Library. Execute the following cell to decompress your extracted dataset:

# %%
import tarfile

with tarfile.open("cifar.tar.gz", "r:gz") as tar:
    tar.extractall()

# %% [markdown]
# A new folder `cifar-100-python` should be created, containing `meta`, `test`, and `train` files. These files are `pickles` and the [CIFAR homepage](https://www.cs.toronto.edu/~kriz/cifar.html) provides a simple script that can be used to load them. We've adapted the script below for you to run:

# %%
import pickle

with open("./cifar-100-python/meta", "rb") as f:
    dataset_meta = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/test", "rb") as f:
    dataset_test = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/train", "rb") as f:
    dataset_train = pickle.load(f, encoding='bytes')

# %%
# Feel free to explore the datasets

dataset_train.keys()
# Out:
# dict_keys([b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data'])

# %% [markdown]
# As documented on the homepage, `b'data'` contains rows of 3073 unsigned integers, representing three channels (red, green, and blue) for one 32x32 pixel image per row.

# %%
32*32*3
# Out:
# 3072

# %% [markdown]
# For a simple gut-check, let's transform one of our images. Each 1024 items in a row is a channel (red, green, then blue). Each 32 items in the channel are a row in the 32x32 image. Using python, we can stack these channels into a 32x32x3 array, and save it as a PNG file:

# %%
import numpy as np

# Each 1024 in a row is a channel (red, green, then blue)
row = dataset_train[b'data'][0]
red, green, blue = row[0:1024], row[1024:2048], row[2048:]

# Each 32 items in the channel are a row in the 32x32 image
red = red.reshape(32,32)
green = green.reshape(32,32)
blue = blue.reshape(32,32)

# Combine the channels into a 32x32x3 image!
combined = np.dstack((red,green,blue))

# %% [markdown]
# For a more concise version, consider the following:

# %%
# All in one:
test_image = np.dstack((
    row[0:1024].reshape(32,32),
    row[1024:2048].reshape(32,32),
    row[2048:].reshape(32,32)
))

# %%
import matplotlib.pyplot as plt
plt.imshow(test_image);

# %% [markdown]
# Looks like a cow! Let's check the label. `dataset_meta` contains label names in order, and `dataset_train` has a list of labels for each row.

# %%
dataset_train[b'fine_labels'][0]
# Out:
# 19

# %% [markdown]
# Our image has a label of `19`, so let's see what the 19th item is in the list of label names.

# %%
print(dataset_meta[b'fine_label_names'][19])
# Out:
# b'cattle'

# %% [markdown]
# Ok! 'cattle' sounds about right. By the way, using the previous two lines we can do:

# %%
n = 0
print(dataset_meta[b'fine_label_names'][dataset_train[b'fine_labels'][n]])
# Out:
# b'cattle'

# %% [markdown]
# Now we know how to check labels, is there a way that we can also check file names? `dataset_train` also contains a `b'filenames'` key. Let's see what we have here:

# %%
print(dataset_train[b'filenames'][0])
# Out:
# b'bos_taurus_s_000507.png'

# %% [markdown]
# "Taurus" is the name of a subspecies of cattle, so this looks like a pretty reasonable filename. To save an image we can also do:

# %%
plt.imsave("file.png", test_image)

# %% [markdown]
# Your new PNG file should now appear in the file explorer -- go ahead and pop it open to see!
#
# Now that you know how to reshape the images, save them as files, and capture their filenames and labels, let's just capture all the bicycles and motorcycles and save them. Scones Unlimited can use a model that tells these apart to route delivery drivers automatically.
#
# In the following cell, identify the label numbers for Bicycles and Motorcycles:

# %%
import pandas as pd

# Todo: Filter the dataset_train and dataset_meta objects to find the label numbers
# for Bicycle and Motorcycles

for n, label in enumerate(dataset_meta[b'fine_label_names']):
    if label in [b'bicycle', b'motorcycle']:
        print(label, '– label', n)
# Out:
# b'bicycle' – label 8
# b'motorcycle' – label 48

# %% [markdown]
# Good job! We only need objects with label 8 and 48 -- this drastically simplifies our handling of the data! Below we construct a dataframe for you, and you can safely drop the rows that don't contain observations about bicycles and motorcycles. Fill in the missing lines below to drop all other rows:

# %%
#Construct the dataframe
df_train = pd.DataFrame({
    "filenames": dataset_train[b'filenames'],
    "labels": dataset_train[b'fine_labels'],
    "row": range(len(dataset_train[b'filenames']))
})

# Drop all rows from df_train where label is not 8 or 48
df_train = df_train.loc[df_train['labels'].isin([8,48])]

# Decode df_train.filenames so they are regular strings
df_train["filenames"] = df_train["filenames"].apply(
    lambda x: x.decode("utf-8")
)


df_test = pd.DataFrame({
    "filenames": dataset_test[b'filenames'],
    "labels": dataset_test[b'fine_labels'],
    "row": range(len(dataset_test[b'filenames']))
})

# Drop all rows from df_test where label is not 8 or 48
df_test = df_test.loc[df_test['labels'].isin([8,48])]

# Decode df_test.filenames so they are regular strings
df_test["filenames"] = df_test["filenames"].apply(
    lambda x: x.decode("utf-8")
)

# %%
# Lemme take a look
df_train.head()
# Out:
#                    filenames  labels  row
# 16         bike_s_000682.png       8   16
# 30         bike_s_000127.png       8   30
# 130       cycle_s_002598.png       8  130
# 152    minibike_s_000824.png      48  152
# 195  motorcycle_s_001856.png      48  195

# %%
df_test.head()
# Out:
#                          filenames  labels  row
# 27        safety_bike_s_000390.png       8   27
# 28               bike_s_000658.png       8   28
# 116        velocipede_s_001744.png       8  116
# 161              bike_s_000643.png       8  161
# 319  ordinary_bicycle_s_000437.png       8  319

# %% [markdown]
# Now that the data is filtered for just our classes, we can save all our images.

# %%
# !mkdir ./train
# !mkdir ./test
# Out:
# mkdir: cannot create directory ‘./train’: File exists
# mkdir: cannot create directory ‘./test’: File exists

# %% [markdown]
# In the previous sections we introduced you to several key snippets of code:
#
# 1. Grabbing the image data:
#
# ```python
# dataset_train[b'data'][0]
# ```
#
# 2. A simple idiom for stacking the image data into the right shape
#
# ```python
# import numpy as np
# np.dstack((
#     row[0:1024].reshape(32,32),
#     row[1024:2048].reshape(32,32),
#     row[2048:].reshape(32,32)
# ))
# ```
#
# 3. A simple `matplotlib` utility for saving images
#
# ```python
# plt.imsave(path+row['filenames'], target)
# ```
#
# Compose these together into a function that saves all the images into the `./test` and `./train` directories. Use the comments in the body of the `save_images` function below to guide your construction of the function:

# %%
import os

def save_images(row, filename, path, dataset):
    
    #Grab the image data in row-major form
    img = dataset[b'data'][row]
            
    # Consolidated stacking/reshaping from earlier
    target = np.dstack((
        img[0:1024].reshape(32,32),
        img[1024:2048].reshape(32,32),
        img[2048:].reshape(32,32)
    ))
    
    # Save the image
    impath = os.path.join(path, filename)
    plt.imsave(impath, target)
    
    # Return any signal data you want for debugging
    return f"Added {filename}"

## save ALL images using the save_images function
# save_images(df_train, './train', dataset_train)
# save_images(df_test, './test', dataset_test)

# %%
# Yeah, ok, saving two images is fine, but I need all of them :D
# Spent a decent amount of time rewriting the above and below functions

for roww in df_train.itertuples():
    print(save_images(roww.row, roww.filenames,"./train", dataset_train))
# Out:
# Added bike_s_000682.png
# Added bike_s_000127.png
# Added cycle_s_002598.png
# Added minibike_s_000824.png
# Added motorcycle_s_001856.png
# Added bicycle_s_000537.png
# Added moped_s_000169.png
# Added motorcycle_s_001453.png
# Added safety_bike_s_000482.png
# Added dirt_bike_s_000124.png
# Added minibike_s_001863.png
# Added minibike_s_001177.png
# Added motorcycle_s_001792.png
# Added minibike_s_001969.png
# Added velocipede_s_001585.png
# Added moped_s_000035.png
# Added bike_s_000256.png
# Added minibike_s_000571.png
# Added motorcycle_s_001119.png
# Added moped_s_000009.png
# Added ordinary_bicycle_s_000023.png
# Added motorcycle_s_001693.png
# Added safety_bicycle_s_001570.png
# Added safety_bike_s_000989.png
# Added bicycle_s_001673.png
# Added ordinary_bicycle_s_000100.png
# Added bike_s_000544.png
# Added motorcycle_s_001368.png
# Added bicycle_s_000392.png
# Added motorbike_s_000221.png
# Added safety_bike_s_000311.png
# Added cycle_s_001745.png
# Added motorcycle_s_002030.png
# Added motorcycle_s_000074.png
# Added cycle_s_002978.png
# Added bike_s_001679.png
# Added bicycle_s_000536.png
# Added bike_s_000926.png
# Added motorcycle_s_000070.png
# Added safety_bicycle_s_000655.png
# Added safety_bicycle_s_000427.png
# Added minibike_s_000324.png
# Added minibike_s_001631.png
# Added motorcycle_s_000629.png
# Added motorcycle_s_000605.png
# Added motorcycle_s_001973.png
# Added bike_s_000555.png
# Added bicycle_s_002762.png
# Added bicycle_s_000778.png
# Added bike_s_001613.png
# Added motorcycle_s_001180.png
# Added minibike_s_001279.png
# Added minibike_s_000451.png
# Added motorbike_s_000346.png
# Added minibike_s_000117.png
# Added bicycle_s_001448.png
# Added motorcycle_s_000790.png
# Added bicycle_s_002373.png
# Added safety_bicycle_s_001202.png
# Added motorcycle_s_000001.png
# Added bike_s_001882.png
# Added bike_s_001113.png
# Added minibike_s_000362.png
# Added cycle_s_000718.png
# Added velocipede_s_001338.png
# Added minibike_s_001972.png
# Added ordinary_bicycle_s_000107.png
# Added motorcycle_s_000776.png
# Added safety_bike_s_000934.png
# Added bicycle_s_002218.png
# Added safety_bicycle_s_001240.png
# Added ordinary_bicycle_s_000355.png
# Added motorcycle_s_000454.png
# Added motorcycle_s_000245.png
# Added minibike_s_000743.png
# Added safety_bike_s_000830.png
# Added minibike_s_001573.png
# Added motorbike_s_000141.png
# Added minibike_s_000652.png
# Added motorbike_s_000058.png
# Added bicycle_s_000279.png
# Added safety_bike_s_001608.png
# Added bicycle_s_000522.png
# Added bicycle_s_002569.png
# Added bicycle_s_000829.png
# Added velocipede_s_000586.png
# Added dirt_bike_s_000017.png
# Added cycle_s_001640.png
# Added bicycle_s_000282.png
# Added motorcycle_s_000713.png
# Added bike_s_000035.png
# Added bike_s_000299.png
# Added minibike_s_002198.png
# Added safety_bicycle_s_001253.png
# Added minibike_s_000110.png
# Added motorcycle_s_001370.png
# Added motorcycle_s_001363.png
# Added ordinary_bicycle_s_000060.png
# Added minibike_s_001653.png
# Added bicycle_s_001338.png
# Added cycle_s_002053.png
# Added velocipede_s_001056.png
# Added minibike_s_000402.png
# Added motorbike_s_000124.png
# Added cycle_s_002638.png
# Added velocipede_s_000949.png
# Added safety_bike_s_000921.png
# Added ordinary_bicycle_s_000297.png
# Added motorcycle_s_001580.png
# Added velocipede_s_000139.png
# Added bicycle_s_000561.png
# Added ordinary_bicycle_s_000161.png
# Added minibike_s_000518.png
# Added motorcycle_s_000167.png
# Added cycle_s_000318.png
# Added velocipede_s_001958.png
# Added ordinary_bicycle_s_000201.png
# Added bike_s_001462.png
# Added bicycle_s_000437.png
# Added velocipede_s_000825.png
# Added safety_bike_s_000100.png
# Added minibike_s_000654.png
# Added bicycle_s_000021.png
# Added moped_s_000030.png
# Added velocipede_s_001142.png
# Added motorbike_s_000117.png
# Added ordinary_bicycle_s_000036.png
# Added motorcycle_s_000787.png
# Added bike_s_000516.png
# Added motorcycle_s_000256.png
# Added bicycle_s_002299.png
# Added velocipede_s_001883.png
# Added motorcycle_s_002143.png
# Added cycle_s_000899.png
# Added bicycle_s_002436.png
# Added safety_bicycle_s_000255.png
# Added minibike_s_000565.png
# Added bike_s_000034.png
# Added motorcycle_s_001064.png
# Added minibike_s_001017.png
# Added motorbike_s_000172.png
# Added motorcycle_s_000923.png
# Added cycle_s_000583.png
# Added motorcycle_s_000991.png
# Added motorbike_s_000541.png
# Added motorcycle_s_001303.png
# Added safety_bike_s_000567.png
# Added minibike_s_000350.png
# Added motorcycle_s_001905.png
# Added bicycle_s_001247.png
# Added bicycle_s_001693.png
# Added bicycle_s_002258.png
# Added safety_bike_s_001552.png
# Added cycle_s_002651.png
# Added bicycle_s_000759.png
# Added motorcycle_s_001176.png
# Added ordinary_bicycle_s_000432.png
# Added minibike_s_000526.png
# Added safety_bicycle_s_001049.png
# Added minibike_s_001827.png
# Added bike_s_001072.png
# Added bike_s_001876.png
# Added minibike_s_001511.png
# Added bike_s_000237.png
# Added motorbike_s_000254.png
# Added bicycle_s_000180.png
# Added safety_bicycle_s_000359.png
# Added motorcycle_s_000220.png
# Added motorcycle_s_002225.png
# Added minibike_s_001185.png
# Added motorcycle_s_000025.png
# Added safety_bike_s_000058.png
# Added dirt_bike_s_000030.png
# Added minibike_s_002009.png
# Added bicycle_s_000753.png
# Added safety_bicycle_s_001320.png
# Added motorcycle_s_001287.png
# Added ordinary_bicycle_s_000451.png
# Added minibike_s_000885.png
# Added motorcycle_s_000418.png
# Added velocipede_s_000282.png
# Added cycle_s_001474.png
# Added bicycle_s_000667.png
# Added minibike_s_001546.png
# Added bicycle_s_001452.png
# Added motorcycle_s_000978.png
# Added motorcycle_s_000447.png
# Added minibike_s_000146.png
# Added motorcycle_s_000300.png
# Added safety_bicycle_s_001381.png
# Added bike_s_001519.png
# Added minibike_s_001689.png
# Added bike_s_001320.png
# Added bike_s_000722.png
# Added motorcycle_s_000508.png
# Added motorcycle_s_002105.png
# Added minibike_s_000165.png
# Added cycle_s_002703.png
# Added ordinary_bicycle_s_000216.png
# Added motorcycle_s_001610.png
# Added cycle_s_002779.png
# Added bicycle_s_000668.png
# Added minibike_s_002186.png
# Added bike_s_002118.png
# Added safety_bike_s_001472.png
# Added ordinary_bicycle_s_000016.png
# Added motorcycle_s_001384.png
# Added motorcycle_s_000431.png
# Added bike_s_000302.png
# Added velocipede_s_000659.png
# Added motorcycle_s_001585.png
# Added bike_s_001027.png
# Added bicycle_s_000396.png
# Added minibike_s_000149.png
# Added velocipede_s_000702.png
# Added ordinary_bicycle_s_000155.png
# Added cycle_s_003122.png
# Added motorbike_s_000021.png
# Added safety_bicycle_s_001026.png
# Added bike_s_001375.png
# Added safety_bicycle_s_000533.png
# Added bike_s_000021.png
# Added minibike_s_000968.png
# Added minibike_s_001873.png
# Added bicycle_s_000463.png
# Added bike_s_001839.png
# Added minibike_s_000340.png
# Added minibike_s_000831.png
# Added motorcycle_s_001273.png
# Added motorcycle_s_000807.png
# Added bicycle_s_000156.png
# Added motorcycle_s_000732.png
# Added dirt_bike_s_000119.png
# Added bicycle_s_000231.png
# Added ordinary_bicycle_s_000056.png
# Added ordinary_bicycle_s_000022.png
# Added safety_bicycle_s_001243.png
# Added motorcycle_s_000894.png
# Added motorcycle_s_001397.png
# Added motorcycle_s_000542.png
# Added motorcycle_s_000834.png
# Added motorcycle_s_001238.png
# Added minibike_s_000567.png
# Added minibike_s_001512.png
# Added bike_s_001945.png
# Added cycle_s_003148.png
# Added safety_bicycle_s_000019.png
# Added safety_bicycle_s_000167.png
# Added motorcycle_s_001407.png
# Added velocipede_s_001225.png
# Added moped_s_000168.png
# Added bicycle_s_000071.png
# Added minibike_s_002030.png
# Added minibike_s_001294.png
# Added minibike_s_001767.png
# Added safety_bike_s_000984.png
# Added bicycle_s_000782.png
# Added ordinary_bicycle_s_000095.png
# Added cycle_s_001286.png
# Added bike_s_001116.png
# Added motorcycle_s_002065.png
# Added ordinary_bicycle_s_000433.png
# Added motorcycle_s_002221.png
# Added safety_bike_s_000054.png
# Added bicycle_s_001174.png
# Added bicycle_s_002222.png
# Added velocipede_s_001361.png
# Added safety_bike_s_001012.png
# Added minibike_s_000244.png
# Added bicycle_s_000861.png
# Added minibike_s_000566.png
# Added motorcycle_s_001244.png
# Added bicycle_s_002715.png
# Added safety_bike_s_000963.png
# Added motorcycle_s_001765.png
# Added velocipede_s_000021.png
# Added motorcycle_s_000580.png
# Added bike_s_001226.png
# Added motorcycle_s_000440.png
# Added motorcycle_s_000144.png
# Added cycle_s_002844.png
# Added minibike_s_000485.png
# Added ordinary_bicycle_s_000426.png
# Added minibike_s_002196.png
# Added bike_s_001897.png
# Added cycle_s_001374.png
# Added motorcycle_s_000585.png
# Added bike_s_000026.png
# Added bicycle_s_000235.png
# Added minibike_s_000108.png
# Added motorcycle_s_000072.png
# Added motorcycle_s_002234.png
# Added bicycle_s_000785.png
# Added motorcycle_s_000669.png
# Added bicycle_s_000051.png
# Added bike_s_001093.png
# Added velocipede_s_000049.png
# Added bike_s_000023.png
# Added motorcycle_s_001696.png
# Added safety_bicycle_s_001113.png
# Added motorcycle_s_000451.png
# Added velocipede_s_000485.png
# Added motorcycle_s_001753.png
# Added cycle_s_001439.png
# Added minibike_s_002038.png
# Added bicycle_s_000147.png
# Added cycle_s_002399.png
# Added motorcycle_s_001565.png
# Added bicycle_s_000159.png
# Added minibike_s_000035.png
# Added safety_bicycle_s_000239.png
# Added safety_bike_s_001640.png
# Added minibike_s_000698.png
# Added minibike_s_000967.png
# Added safety_bike_s_000381.png
# Added motorcycle_s_000216.png
# Added bike_s_000855.png
# Added motorcycle_s_001715.png
# Added motorcycle_s_002275.png
# Added safety_bike_s_001338.png
# Added safety_bicycle_s_001705.png
# Added minibike_s_000855.png
# Added bicycle_s_002132.png
# Added minibike_s_000218.png
# Added safety_bike_s_000178.png
# Added motorcycle_s_001584.png
# Added safety_bicycle_s_000162.png
# Added motorcycle_s_001392.png
# Added bicycle_s_001814.png
# Added motorbike_s_000362.png
# Added minibike_s_000519.png
# Added minibike_s_001417.png
# Added safety_bike_s_000277.png
# Added cycle_s_002090.png
# Added bicycle_s_001168.png
# Added minibike_s_000498.png
# Added motorcycle_s_001400.png
# Added motorcycle_s_000320.png
# Added minibike_s_001734.png
# Added cycle_s_002659.png
# Added bike_s_000990.png
# Added velocipede_s_000358.png
# Added safety_bicycle_s_000568.png
# Added motorcycle_s_000312.png
# Added motorcycle_s_001686.png
# Added cycle_s_001472.png
# Added minibike_s_000064.png
# Added safety_bike_s_001784.png
# Added motorcycle_s_002236.png
# Added minibike_s_000020.png
# Added motorcycle_s_001182.png
# Added bicycle_s_000781.png
# Added ordinary_bicycle_s_000167.png
# Added cycle_s_002666.png
# Added dirt_bike_s_000134.png
# Added bike_s_000015.png
# Added bike_s_001767.png
# Added motorcycle_s_001790.png
# Added bike_s_001915.png
# Added bike_s_001415.png
# Added motorbike_s_000578.png
# Added safety_bicycle_s_000532.png
# Added ordinary_bicycle_s_000049.png
# Added minibike_s_001639.png
# Added bike_s_000129.png
# Added minibike_s_001565.png
# Added bike_s_002203.png
# Added minibike_s_000401.png
# Added safety_bicycle_s_001608.png
# Added velocipede_s_000670.png
# Added safety_bicycle_s_000207.png
# Added motorcycle_s_001853.png
# Added bike_s_002222.png
# Added motorcycle_s_000004.png
# Added motorcycle_s_000496.png
# Added motorcycle_s_001492.png
# Added bike_s_001761.png
# Added velocipede_s_001299.png
# Added bike_s_000040.png
# Added cycle_s_003162.png
# Added velocipede_s_001880.png
# Added bike_s_002139.png
# Added bicycle_s_001583.png
# Added safety_bicycle_s_001706.png
# Added bike_s_001200.png
# Added motorcycle_s_000699.png
# Added cycle_s_000492.png
# Added cycle_s_000222.png
# Added motorcycle_s_002162.png
# Added minibike_s_000409.png
# Added cycle_s_001735.png
# Added bike_s_000657.png
# Added safety_bike_s_000643.png
# Added bike_s_000506.png
# Added minibike_s_001348.png
# Added moped_s_000065.png
# Added bicycle_s_002729.png
# Added bicycle_s_001687.png
# Added bicycle_s_002338.png
# Added motorcycle_s_000459.png
# Added bike_s_000593.png
# Added velocipede_s_001422.png
# Added ordinary_bicycle_s_000347.png
# Added minibike_s_001870.png
# Added bicycle_s_001757.png
# Added motorcycle_s_001016.png
# Added motorbike_s_000041.png
# Added bike_s_000522.png
# Added ordinary_bicycle_s_000104.png
# Added bike_s_000397.png
# Added minibike_s_000802.png
# Added trail_bike_s_000016.png
# Added motorcycle_s_000686.png
# Added velocipede_s_001935.png
# Added safety_bike_s_000165.png
# Added motorbike_s_000308.png
# Added bike_s_000018.png
# Added cycle_s_001976.png
# Added minibike_s_000741.png
# Added motorcycle_s_001236.png
# Added moped_s_000071.png
# Added bike_s_000164.png
# Added bike_s_001739.png
# Added bicycle_s_001388.png
# Added bicycle_s_000149.png
# Added motorcycle_s_002197.png
# Added motorcycle_s_000277.png
# Added motorcycle_s_001690.png
# Added minibike_s_002048.png
# Added motorcycle_s_000253.png
# Added safety_bike_s_001010.png
# Added motorcycle_s_000785.png
# Added ordinary_bicycle_s_000387.png
# Added cycle_s_001309.png
# Added motorcycle_s_002316.png
# Added motorcycle_s_000340.png
# Added moped_s_000124.png
# Added minibike_s_001917.png
# Added bicycle_s_000951.png
# Added motorcycle_s_000002.png
# Added motorcycle_s_001063.png
# Added motorcycle_s_001641.png
# Added bicycle_s_002129.png
# Added minibike_s_002182.png
# Added minibike_s_000427.png
# Added motorcycle_s_001438.png
# Added motorcycle_s_000126.png
# Added minibike_s_001865.png
# Added motorcycle_s_000456.png
# Added motorcycle_s_000252.png
# Added bicycle_s_000043.png
# Added bicycle_s_001928.png
# Added safety_bike_s_000173.png
# Added motorcycle_s_000696.png
# Added motorcycle_s_001413.png
# Added safety_bicycle_s_001303.png
# Added motorcycle_s_001220.png
# Added safety_bicycle_s_000079.png
# Added bicycle_s_001681.png
# Added cycle_s_002015.png
# Added cycle_s_002746.png
# Added minibike_s_001250.png
# Added safety_bicycle_s_000303.png
# Added bike_s_000392.png
# Added minibike_s_000408.png
# Added safety_bike_s_001355.png
# Added motorcycle_s_000076.png
# Added safety_bicycle_s_000322.png
# Added bike_s_002090.png
# Added motorcycle_s_000796.png
# Added motorbike_s_000225.png
# Added motorcycle_s_000050.png
# Added safety_bike_s_001257.png
# Added bicycle_s_001203.png
# Added safety_bicycle_s_001085.png
# Added motorcycle_s_002222.png
# Added safety_bicycle_s_001639.png
# Added velocipede_s_001222.png
# Added minibike_s_000392.png
# Added ordinary_bicycle_s_000308.png
# Added motorcycle_s_001896.png
# Added motorcycle_s_000325.png
# Added bicycle_s_000986.png
# Added safety_bicycle_s_000373.png
# Added safety_bicycle_s_000348.png
# Added bicycle_s_002005.png
# Added minibike_s_002130.png
# Added safety_bike_s_000867.png
# Added bicycle_s_002475.png
# Added minibike_s_001193.png
# Added minibike_s_001366.png
# Added motorcycle_s_001711.png
# Added minibike_s_001275.png
# Added velocipede_s_001907.png
# Added motorcycle_s_000207.png
# Added motorcycle_s_001409.png
# Added safety_bicycle_s_000261.png
# Added minibike_s_000738.png
# Added motorcycle_s_001106.png
# Added safety_bike_s_000198.png
# Added minibike_s_001479.png
# Added velocipede_s_000430.png
# Added bicycle_s_001409.png
# Added motorcycle_s_000938.png
# Added motorcycle_s_000941.png
# Added bicycle_s_000038.png
# Added minibike_s_001016.png
# Added velocipede_s_001200.png
# Added bike_s_002109.png
# Added cycle_s_002092.png
# Added motorcycle_s_002066.png
# Added motorcycle_s_001920.png
# Added minibike_s_000459.png
# Added bicycle_s_001904.png
# Added minibike_s_001996.png
# Added motorcycle_s_001611.png
# Added velocipede_s_001141.png
# Added minibike_s_001747.png
# Added safety_bicycle_s_001029.png
# Added ordinary_bicycle_s_000029.png
# Added minibike_s_002163.png
# Added safety_bike_s_001148.png
# Added cycle_s_003008.png
# Added bicycle_s_000099.png
# Added minibike_s_000429.png
# Added bike_s_000003.png
# Added cycle_s_002178.png
# Added cycle_s_000639.png
# Added motorcycle_s_000734.png
# Added motorcycle_s_000309.png
# Added bicycle_s_000371.png
# Added minibike_s_001270.png
# Added minibike_s_000914.png
# Added moped_s_000021.png
# Added motorcycle_s_000242.png
# Added minibike_s_000314.png
# Added motorcycle_s_000698.png
# Added motorcycle_s_001360.png
# Added ordinary_bicycle_s_000157.png
# Added minibike_s_001838.png
# Added bicycle_s_002247.png
# Added motorcycle_s_000027.png
# Added minibike_s_000906.png
# Added safety_bicycle_s_000500.png
# Added minibike_s_002146.png
# Added motorcycle_s_001242.png
# Added motorcycle_s_001707.png
# Added cycle_s_003043.png
# Added safety_bicycle_s_001109.png
# Added bike_s_001131.png
# Added motorcycle_s_001118.png
# Added bike_s_001418.png
# Added bicycle_s_002550.png
# Added bicycle_s_002100.png
# Added motorcycle_s_000933.png
# Added bicycle_s_002624.png
# Added safety_bicycle_s_001063.png
# Added motorbike_s_000361.png
# Added safety_bicycle_s_000193.png
# Added safety_bicycle_s_000092.png
# Added motorcycle_s_000009.png
# Added bicycle_s_001554.png
# Added motorcycle_s_001297.png
# Added safety_bicycle_s_000296.png
# Added safety_bike_s_001371.png
# Added bicycle_s_001569.png
# Added motorcycle_s_001536.png
# Added safety_bicycle_s_001659.png
# Added ordinary_bicycle_s_000102.png
# Added bike_s_002215.png
# Added bicycle_s_002410.png
# Added cycle_s_003147.png
# Added bicycle_s_002759.png
# Added minibike_s_000335.png
# Added safety_bike_s_000848.png
# Added velocipede_s_000807.png
# Added bike_s_000024.png
# Added minibike_s_000435.png
# Added minibike_s_001498.png
# Added velocipede_s_001166.png
# Added motorcycle_s_001012.png
# Added velocipede_s_000330.png
# Added motorcycle_s_000032.png
# Added minibike_s_001597.png
# Added motorcycle_s_002298.png
# Added minibike_s_000102.png
# Added motorcycle_s_001507.png
# Added motorbike_s_000022.png
# Added motorcycle_s_000594.png
# Added minibike_s_001539.png
# Added bicycle_s_001228.png
# Added minibike_s_001344.png
# Added motorcycle_s_002271.png
# Added motorcycle_s_000791.png
# Added ordinary_bicycle_s_000218.png
# Added motorcycle_s_000221.png
# Added minibike_s_001691.png
# Added motorcycle_s_001209.png
# Added ordinary_bicycle_s_000101.png
# Added motorcycle_s_001326.png
# Added minibike_s_001249.png
# Added bicycle_s_000408.png
# Added minibike_s_000520.png
# Added minibike_s_002218.png
# Added minibike_s_001458.png
# Added moped_s_000034.png
# Added motorbike_s_000119.png
# Added motorcycle_s_001027.png
# Added cycle_s_001477.png
# Added motorcycle_s_001710.png
# Added minibike_s_000434.png
# Added motorcycle_s_000979.png
# Added safety_bike_s_001289.png
# Added safety_bike_s_001560.png
# Added minibike_s_000011.png
# Added bicycle_s_001642.png
# Added minibike_s_000527.png
# Added bicycle_s_001245.png
# Added bike_s_000934.png
# Added velocipede_s_001244.png
# Added velocipede_s_001882.png
# Added bike_s_001683.png
# Added minibike_s_000127.png
# Added bicycle_s_001002.png
# Added moped_s_000044.png
# Added bike_s_000025.png
# Added minibike_s_000690.png
# Added minibike_s_000022.png
# Added motorcycle_s_001196.png
# Added ordinary_bicycle_s_000269.png
# Added cycle_s_002503.png
# Added ordinary_bicycle_s_000097.png
# Added safety_bike_s_000009.png
# Added safety_bike_s_000015.png
# Added minibike_s_000613.png
# Added motorcycle_s_001017.png
# Added minibike_s_000203.png
# Added velocipede_s_001489.png
# Added minibike_s_000813.png
# Added safety_bicycle_s_000425.png
# Added motorcycle_s_001622.png
# Added motorcycle_s_000593.png
# Added minibike_s_000116.png
# Added motorcycle_s_001563.png
# Added cycle_s_001875.png
# Added safety_bike_s_001590.png
# Added minibike_s_000830.png
# Added minibike_s_000570.png
# Added bike_s_001380.png
# Added moped_s_000236.png
# Added motorcycle_s_000339.png
# Added safety_bike_s_001465.png
# Added motorcycle_s_001714.png
# Added minibike_s_001191.png
# Added cycle_s_002882.png
# Added bicycle_s_000822.png
# Added bike_s_001827.png
# Added ordinary_bicycle_s_000110.png
# Added minibike_s_000293.png
# Added motorcycle_s_000249.png
# Added ordinary_bicycle_s_000154.png
# Added motorcycle_s_001527.png
# Added motorcycle_s_001033.png
# Added motorcycle_s_001709.png
# Added bicycle_s_001348.png
# Added minibike_s_002194.png
# Added minibike_s_001079.png
# Added bicycle_s_000017.png
# Added minibike_s_001638.png
# Added motorcycle_s_001587.png
# Added motorcycle_s_000486.png
# Added minibike_s_001880.png
# Added dirt_bike_s_000003.png
# Added bike_s_000336.png
# Added minibike_s_002115.png
# Added motorbike_s_000449.png
# Added motorcycle_s_000304.png
# Added motorcycle_s_000022.png
# Added motorcycle_s_001623.png
# Added motorbike_s_000223.png
# Added motorcycle_s_000290.png
# Added safety_bicycle_s_001327.png
# Added bike_s_002288.png
# Added minibike_s_000569.png
# Added bike_s_002047.png
# Added motorcycle_s_002031.png
# Added bike_s_000062.png
# Added cycle_s_000871.png
# Added motorcycle_s_001778.png
# Added velocipede_s_000010.png
# Added motorcycle_s_001247.png
# Added motorcycle_s_000724.png
# Added velocipede_s_001637.png
# Added motorcycle_s_000291.png

# %%
# That's better, now test set

for roww in df_test.itertuples():
    print(save_images(roww.row, roww.filenames,"./test", dataset_test))
# Out:
# Added safety_bike_s_000390.png
# Added bike_s_000658.png
# Added velocipede_s_001744.png
# Added bike_s_000643.png
# Added ordinary_bicycle_s_000437.png
# Added motorcycle_s_000323.png
# Added safety_bike_s_001253.png
# Added cycle_s_001306.png
# Added velocipede_s_000863.png
# Added bicycle_s_000479.png
# Added minibike_s_002173.png
# Added motorcycle_s_000352.png
# Added bike_s_000801.png
# Added motorbike_s_000433.png
# Added bike_s_001068.png
# Added motorcycle_s_000963.png
# Added bike_s_001852.png
# Added motorcycle_s_000139.png
# Added motorbike_s_000465.png
# Added bicycle_s_000513.png
# Added cycle_s_002305.png
# Added motorcycle_s_000615.png
# Added moped_s_000306.png
# Added minibike_s_000052.png
# Added bike_s_001342.png
# Added cycle_s_001297.png
# Added motorcycle_s_001955.png
# Added cycle_s_001953.png
# Added motorcycle_s_000494.png
# Added motorcycle_s_001249.png
# Added velocipede_s_000292.png
# Added minibike_s_001651.png
# Added bicycle_s_001102.png
# Added safety_bike_s_001132.png
# Added moped_s_000007.png
# Added motorcycle_s_000211.png
# Added cycle_s_000970.png
# Added motorcycle_s_002126.png
# Added minibike_s_001732.png
# Added minibike_s_001867.png
# Added minibike_s_002227.png
# Added cycle_s_000068.png
# Added minibike_s_000880.png
# Added moped_s_000033.png
# Added bicycle_s_001107.png
# Added bike_s_002116.png
# Added bike_s_001738.png
# Added bike_s_002009.png
# Added minibike_s_000947.png
# Added bike_s_001159.png
# Added safety_bike_s_001065.png
# Added motorbike_s_000005.png
# Added minibike_s_000075.png
# Added motorcycle_s_001164.png
# Added motorcycle_s_000679.png
# Added motorcycle_s_001892.png
# Added bike_s_000694.png
# Added velocipede_s_000106.png
# Added velocipede_s_000001.png
# Added motorcycle_s_002177.png
# Added motorbike_s_000126.png
# Added safety_bicycle_s_001286.png
# Added motorcycle_s_001936.png
# Added safety_bike_s_001087.png
# Added cycle_s_001648.png
# Added minibike_s_000801.png
# Added motorcycle_s_000427.png
# Added minibike_s_001089.png
# Added motorcycle_s_000530.png
# Added velocipede_s_001232.png
# Added motorcycle_s_001261.png
# Added velocipede_s_001466.png
# Added motorcycle_s_001269.png
# Added bicycle_s_000776.png
# Added motorcycle_s_001348.png
# Added motorcycle_s_002026.png
# Added safety_bike_s_000540.png
# Added safety_bicycle_s_000280.png
# Added bike_s_000131.png
# Added cycle_s_000010.png
# Added minibike_s_000828.png
# Added minibike_s_000288.png
# Added velocipede_s_001355.png
# Added safety_bicycle_s_001575.png
# Added safety_bike_s_001690.png
# Added cycle_s_001044.png
# Added motorcycle_s_000063.png
# Added velocipede_s_001379.png
# Added minibike_s_001441.png
# Added motorcycle_s_000797.png
# Added velocipede_s_001790.png
# Added motorbike_s_000135.png
# Added cycle_s_002613.png
# Added motorcycle_s_001960.png
# Added minibike_s_000913.png
# Added motorcycle_s_000685.png
# Added ordinary_bicycle_s_000431.png
# Added minibike_s_002051.png
# Added motorcycle_s_000446.png
# Added velocipede_s_001699.png
# Added minibike_s_000792.png
# Added bicycle_s_002458.png
# Added minibike_s_000505.png
# Added minibike_s_000573.png
# Added velocipede_s_000369.png
# Added moped_s_000064.png
# Added minibike_s_001893.png
# Added motorcycle_s_000878.png
# Added motorcycle_s_000042.png
# Added motorcycle_s_000606.png
# Added minibike_s_002230.png
# Added motorcycle_s_001519.png
# Added motorcycle_s_000512.png
# Added cycle_s_001915.png
# Added safety_bike_s_000541.png
# Added safety_bike_s_000192.png
# Added bicycle_s_000030.png
# Added motorcycle_s_001385.png
# Added minibike_s_000960.png
# Added safety_bike_s_000791.png
# Added bike_s_000071.png
# Added motorcycle_s_000876.png
# Added ordinary_bicycle_s_000350.png
# Added motorcycle_s_000602.png
# Added motorcycle_s_000222.png
# Added minibike_s_000309.png
# Added motorcycle_s_001679.png
# Added minibike_s_001473.png
# Added velocipede_s_001633.png
# Added safety_bike_s_000438.png
# Added safety_bicycle_s_000315.png
# Added motorcycle_s_002112.png
# Added bike_s_000163.png
# Added bicycle_s_000059.png
# Added bicycle_s_001789.png
# Added safety_bike_s_000699.png
# Added motorbike_s_000324.png
# Added motorcycle_s_000485.png
# Added motorcycle_s_001687.png
# Added minibike_s_000497.png
# Added minibike_s_001547.png
# Added minibike_s_000055.png
# Added ordinary_bicycle_s_000169.png
# Added minibike_s_000290.png
# Added velocipede_s_001335.png
# Added bicycle_s_001804.png
# Added safety_bike_s_000488.png
# Added bike_s_001216.png
# Added motorbike_s_000121.png
# Added bike_s_001073.png
# Added safety_bicycle_s_001153.png
# Added motorcycle_s_000171.png
# Added velocipede_s_000041.png
# Added motorcycle_s_001782.png
# Added motorbike_s_000629.png
# Added bicycle_s_000977.png
# Added motorcycle_s_001906.png
# Added bike_s_002208.png
# Added minibike_s_000254.png
# Added safety_bicycle_s_001322.png
# Added bike_s_000041.png
# Added bicycle_s_000031.png
# Added bicycle_s_000779.png
# Added velocipede_s_001277.png
# Added safety_bike_s_001088.png
# Added motorcycle_s_001971.png
# Added bike_s_001784.png
# Added motorcycle_s_000825.png
# Added dirt_bike_s_000001.png
# Added cycle_s_001214.png
# Added cycle_s_002964.png
# Added ordinary_bicycle_s_000284.png
# Added bicycle_s_002735.png
# Added motorcycle_s_000450.png
# Added motorcycle_s_000049.png
# Added motorcycle_s_000866.png
# Added velocipede_s_001201.png
# Added bike_s_000457.png
# Added bike_s_000330.png
# Added minibike_s_001605.png
# Added minibike_s_000398.png
# Added motorcycle_s_000007.png
# Added motorcycle_s_000040.png
# Added motorcycle_s_000739.png
# Added motorbike_s_000333.png
# Added safety_bike_s_001481.png
# Added ordinary_bicycle_s_000158.png
# Added motorcycle_s_001508.png
# Added motorcycle_s_000060.png
# Added cycle_s_002661.png
# Added bicycle_s_001047.png
# Added bicycle_s_000777.png
# Added safety_bicycle_s_000235.png
# Added bike_s_000487.png
# Added ordinary_bicycle_s_000113.png
# Added trail_bike_s_000073.png
# Added bike_s_000941.png
# Added motorcycle_s_000141.png
# Added ordinary_bicycle_s_000105.png
# Added bicycle_s_001218.png

# %% [markdown]
# ### 3. Load the data
#
# Now we can load the data into S3.
#
# Using the sagemaker SDK grab the current region, execution role, and bucket.

# %%
import sagemaker

session = sagemaker.Session()

bucket = 'vedrauxx'
print("Default Bucket: {}".format(bucket))

region = session.boto_region_name
print("AWS Region: {}".format(region))

role = sagemaker.get_execution_role()
print("RoleArn: {}".format(role))
# Out:
# Default Bucket: vedrauxx
# AWS Region: us-east-1
# RoleArn: arn:aws:iam::961953052480:role/service-role/AmazonSageMaker-ExecutionRole-20230826T173413

# %% [markdown]
# With this data we can easily sync your data up into S3!

# %%
import os

os.environ["DEFAULT_S3_BUCKET"] = bucket
# !aws s3 sync ./train s3://${DEFAULT_S3_BUCKET}/train/
# !aws s3 sync ./test s3://${DEFAULT_S3_BUCKET}/test/

# %% [markdown]
# And that's it! You can check the bucket and verify that the items were uploaded.
#
# ## Model Training
#
# For Image Classification, Sagemaker [also expects metadata](https://docs.aws.amazon.com/sagemaker/latest/dg/image-classification.html) e.g. in the form of TSV files with labels and filepaths. We can generate these using our Pandas DataFrames from earlier:

# %%
def to_metadata_file(df, prefix):
    df["s3_path"] = df["filenames"]
    df["labels"] = df["labels"].apply(lambda x: 0 if x==8 else 1)
    return df[["row", "labels", "s3_path"]].to_csv(
        f"{prefix}.lst", sep="\t", index=False, header=False
    )
    
to_metadata_file(df_train.copy(), "train")
to_metadata_file(df_test.copy(), "test")

# %% [markdown]
# We can also upload our manifest files:

# %%
import boto3

# Upload files
boto3.Session().resource('s3').Bucket(
    bucket).Object('train.lst').upload_file('./train.lst')
boto3.Session().resource('s3').Bucket(
    bucket).Object('test.lst').upload_file('./test.lst')

# %% [markdown]
# Using the `bucket` and `region` info we can get the latest prebuilt container to run our training job, and define an output location on our s3 bucket for the model. Use the `image_uris` function from the SageMaker SDK to retrieve the latest `image-classification` image below:

# %%
# Use the image_uris function to retrieve the latest 'image-classification' image 
algo_image = sagemaker.image_uris.retrieve(framework = 'image-classification', region = region)
s3_output_location = f"s3://{bucket}/models/image_model"

# %% [markdown]
# We're ready to create an estimator! Create an estimator `img_classifier_model` that uses one instance of `ml.p3.2xlarge`. Ensure that y ou use the output location we defined above - we'll be referring to that later!

# %%
img_classifier_model=sagemaker.estimator.Estimator(
    image_uri = algo_image,
    role = role,
    instance_count = 1,
    # Remember, that the notebook was tested on ml.t3.medium
    # Could try it if instances fail again
    # Instances failed again, nobody solves the issue, why nothing ever works on Udacity?
    instance_type = 'ml.g4dn.xlarge',
    output_path = s3_output_location,
    sagemaker_session = session    
)

# %%
# I made a pause after training a model
# the above cell does not work anymore, as I get the error
# ValueError: Estimator is not associated with a training job
# so I created this cell to use the trained model, not to train a new one

img_classifier_model = sagemaker.estimator.Estimator.attach('image-classification-2023-08-30-22-25-53-812')
# Out:
# 2023-08-30 22:37:04 Starting - Preparing the instances for training
# 2023-08-30 22:37:04 Downloading - Downloading input data
# 2023-08-30 22:37:04 Training - Training image download completed. Training in progress.
# 2023-08-30 22:37:04 Uploading - Uploading generated training model
# 2023-08-30 22:37:04 Completed - Training job completed

# %% [markdown]
# We can also set a few key hyperparameters and define the inputs for our model:

# %%
img_classifier_model.set_hyperparameters(
    image_shape = '3,32,32',
    num_classes = 2,
    num_training_samples = len(df_train) 
)

# %% [markdown]
# The `image-classification` image uses four input channels with very specific input parameters. For convenience, we've provided them below:

# %%
from sagemaker.debugger import Rule, rule_configs
from sagemaker.session import TrainingInput
model_inputs = {
        "train": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train/",
            content_type="application/x-image"
        ),
        "validation": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test/",
            content_type="application/x-image"
        ),
        "train_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train.lst",
            content_type="application/x-image"
        ),
        "validation_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test.lst",
            content_type="application/x-image"
        )
}

# %% [markdown]
# Great, now we can train the model using the model_inputs. In the cell below, call the `fit` method on our model,:

# %%
img_classifier_model.fit(model_inputs)
# Out:
# INFO:sagemaker:Creating training-job with name: image-classification-2023-08-30-22-25-53-812
# 2023-08-30 22:25:53 Starting - Starting the training job...
# 2023-08-30 22:26:08 Starting - Preparing the instances for training......
# 2023-08-30 22:27:24 Downloading - Downloading input data.........
# 2023-08-30 22:28:35 Training - Downloading the training image............
# 2023-08-30 22:30:41 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Wed Aug 30 22:30:52 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       On  | 00000000:00:1E.0 Off |                    0 |
# | N/A   36C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 535.54.03.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# [08/30/2023 22:30:55 INFO 140007935502144] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/image_classification/default-input.json: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,224,224', 'precision_dtype': 'float32'}
# [08/30/2023 22:30:55 INFO 140007935502144] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'image_shape': '3,32,32', 'num_classes': '2', 'num_training_samples': '1000'}
# [08/30/2023 22:30:55 INFO 140007935502144] Final configuration: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,32,32', 'precision_dtype': 'float32', 'num_classes': '2', 'num_training_samples': '1000'}
# [08/30/2023 22:30:55 INFO 140007935502144] Searching for .lst files in /opt/ml/input/data/train_lst.
# [08/30/2023 22:30:55 INFO 140007935502144] Creating record files for train.lst
# [08/30/2023 22:30:56 INFO 140007935502144] Done creating record files...
# [08/30/2023 22:30:56 INFO 140007935502144] Searching for .lst files in /opt/ml/input/data/validation_lst.
# [08/30/2023 22:30:56 INFO 140007935502144] Creating record files for test.lst
# [08/30/2023 22:30:56 INFO 140007935502144] Done creating record files...
# [08/30/2023 22:30:56 INFO 140007935502144] use_pretrained_model: 0
# [08/30/2023 22:30:56 INFO 140007935502144] multi_label: 0
# [08/30/2023 22:30:56 INFO 140007935502144] Performing random weight initialization
# [08/30/2023 22:30:56 INFO 140007935502144] ---- Parameters ----
# [08/30/2023 22:30:56 INFO 140007935502144] num_layers: 152
# [08/30/2023 22:30:56 INFO 140007935502144] data type: <class 'numpy.float32'>
# [08/30/2023 22:30:56 INFO 140007935502144] epochs: 30
# [08/30/2023 22:30:56 INFO 140007935502144] optimizer: sgd
# [08/30/2023 22:30:56 INFO 140007935502144] momentum: 0.9
# [08/30/2023 22:30:56 INFO 140007935502144] weight_decay: 0.0001
# [08/30/2023 22:30:56 INFO 140007935502144] learning_rate: 0.1
# [08/30/2023 22:30:56 INFO 140007935502144] num_training_samples: 1000
# [08/30/2023 22:30:56 INFO 140007935502144] mini_batch_size: 32
# [08/30/2023 22:35:58 INFO 140007935502144] Epoch[26] Validation-accuracy=0.880208
# [08/30/2023 22:35:58 INFO 140007935502144] Storing the best model with validation accuracy: 0.880208
# [08/30/2023 22:35:59 INFO 140007935502144] Saved checkpoint to "/opt/ml/model/image-classification-0027.params"
# [08/30/2023 22:36:05 INFO 140007935502144] Epoch[27] Batch [20]#011Speed: 98.031 samples/sec#011accuracy=0.983631
# [08/30/2023 22:36:08 INFO 140007935502144] Epoch[27] Train-accuracy=0.979839
# [08/30/2023 22:36:08 INFO 140007935502144] Epoch[27] Time cost=9.716
# [08/30/2023 22:36:09 INFO 140007935502144] Epoch[27] Validation-accuracy=0.839286
# [08/30/2023 22:36:16 INFO 140007935502144] Epoch[28] Batch [20]#011Speed: 97.205 samples/sec#011accuracy=0.962798
# [08/30/2023 22:36:20 INFO 140007935502144] Epoch[28] Train-accuracy=0.961694
# [08/30/2023 22:36:20 INFO 140007935502144] Epoch[28] Time cost=9.766
# [08/30/2023 22:36:20 INFO 140007935502144] Epoch[28] Validation-accuracy=0.833333
# [08/30/2023 22:36:27 INFO 140007935502144] Epoch[29] Batch [20]#011Speed: 98.378 samples/sec#011accuracy=0.977679
# [08/30/2023 22:36:30 INFO 140007935502144] Epoch[29] Train-accuracy=0.979839
# [08/30/2023 22:36:30 INFO 140007935502144] Epoch[29] Time cost=9.649
# [08/30/2023 22:36:31 INFO 140007935502144] Epoch[29] Validation-accuracy=0.838542
#
# 2023-08-30 22:37:04 Uploading - Uploading generated training model
# 2023-08-30 22:37:04 Completed - Training job completed
# Training seconds: 579
# Billable seconds: 579

# %% [markdown]
# If all goes well, you'll end up with a model topping out above `.8` validation accuracy. With only 1000 training samples in the CIFAR dataset, that's pretty good. We could definitely pursue data augmentation & gathering more samples to help us improve further, but for now let's proceed to deploy our model.
#
# ### Getting ready to deploy
#
# To begin with, let's configure Model Monitor to track our deployment. We'll define a `DataCaptureConfig` below:

# %%
from sagemaker.model_monitor import DataCaptureConfig

data_capture_config = DataCaptureConfig(
    enable_capture = True,
    sampling_percentage = 100,
    destination_s3_uri = f"s3://{bucket}/data_capture"
)

# %% [markdown]
# Note the `destination_s3_uri` parameter: At the end of the project, we can explore the `data_capture` directory in S3 to find crucial data about the inputs and outputs Model Monitor has observed on our model endpoint over time.
#
# With that done, deploy your model on a single `ml.m5.xlarge` instance with the data capture config attached:

# %%
deployment = img_classifier_model.deploy(
    initial_instance_count = 1,
    instance_type = 'ml.g4dn.xlarge',
    data_capture_config = data_capture_config
    )

endpoint = deployment.endpoint_name
print(endpoint)
# Out:
# -------!image-classification-2023-09-01-17-32-58-596

# %% [markdown]
# Note the endpoint name for later as well.
#
# Next, instantiate a Predictor:

# %%
from sagemaker.predictor import Predictor 
predictor = Predictor(endpoint)

# %% [markdown]
# In the code snippet below we are going to prepare one of your saved images for prediction. Use the predictor to process the `payload`.

# %%
from sagemaker.serializers import IdentitySerializer
import base64

predictor.serializer = IdentitySerializer("image/png")
with open("./test/bicycle_s_001789.png", "rb") as f:
    payload = f.read()

    
inference = predictor.predict(payload)

# %% [markdown]
# Your `inference` object is an array of two values, the predicted probability value for each of your classes (bicycle and motorcycle respectively.) So, for example, a value of `b'[0.91, 0.09]'` indicates the probability of being a bike is 91% and being a motorcycle is 9%.

# %%
print(inference)
# Out:
# b'[0.9995319843292236, 0.00046799605479463935]'

# %% [markdown]
# ### Draft Lambdas and Step Function Workflow
#
# Your operations team uses Step Functions to orchestrate serverless workflows. One of the nice things about Step Functions is that [workflows can call other workflows](https://docs.aws.amazon.com/step-functions/latest/dg/connect-stepfunctions.html), so the team can easily plug your workflow into the broader production architecture for Scones Unlimited.
#
# In this next stage you're going to write and deploy three Lambda functions, and then use the Step Functions visual editor to chain them together! Our functions are going to work with a simple data object:
#
# ```python
# {
#     "inferences": [], # Output of predictor.predict
#     "s3_key": "", # Source data S3 key
#     "s3_bucket": "", # Source data S3 bucket
#     "image_data": ""  # base64 encoded string containing the image data
# }
# ```
#
# A good test object that you can use for Lambda tests and Step Function executions, throughout the next section, might look like this:
#
# ```python
# {
#   "image_data": "",
#   "s3_bucket": MY_BUCKET_NAME, # Fill in with your bucket
#   "s3_key": "test/bicycle_s_000513.png"
# }
# ```
#
# Using these fields, your functions can read and write the necessary data to execute your workflow. Let's start with the first function. Your first Lambda function will copy an object from S3, base64 encode it, and then return it to the step function as `image_data` in an event.
#
# Go to the Lambda dashboard and create a new Lambda function with a descriptive name like "serializeImageData" and select thr 'Python 3.8' runtime. Add the same permissions as the SageMaker role you created earlier. (Reminder: you do this in the Configuration tab under "Permissions"). Once you're ready, use the starter code below to craft your Lambda handler:
#
# ```python
# import json
# import boto3
# import base64
#
# s3 = boto3.client('s3')
#
# def lambda_handler(event, context):
#     """A function to serialize target data from S3"""
#
#     # Get the s3 address from the Step Function event input
#     key = ## TODO: fill in
#     bucket = ## TODO: fill in
#
#     # Download the data from s3 to /tmp/image.png
#     ## TODO: fill in
#
#     # We read the data from a file
#     with open("/tmp/image.png", "rb") as f:
#         image_data = base64.b64encode(f.read())
#
#     # Pass the data back to the Step Function
#     print("Event:", event.keys())
#     return {
#         'statusCode': 200,
#         'body': {
#             "image_data": image_data,
#             "s3_bucket": bucket,
#             "s3_key": key,
#             "inferences": []
#         }
#     }
# ```
#
# The next function is responsible for the classification part - we're going to take the image output from the previous function, decode it, and then pass inferences back to the the Step Function.
#
# Because this Lambda will have runtime dependencies (i.e. the SageMaker SDK) you'll need to package them in your function. *Key reading:* https://docs.aws.amazon.com/lambda/latest/dg/python-package-create.html#python-package-create-with-dependency
#
# Create a new Lambda function with the same rights and a descriptive name, then fill in the starter code below for your classifier Lambda.
#
# ```python
# import json
# import sagemaker
# import base64
# from sagemaker.serializers import IdentitySerializer
#
# # Fill this in with the name of your deployed model
# ENDPOINT = ## TODO: fill in
#
# def lambda_handler(event, context):
#
#     # Decode the image data
#     image = base64.b64decode(## TODO: fill in)
#
#     # Instantiate a Predictor
#     predictor = ## TODO: fill in
#
#     # For this model the IdentitySerializer needs to be "image/png"
#     predictor.serializer = IdentitySerializer("image/png")
#
#     # Make a prediction:
#     inferences = ## TODO: fill in
#
#     # We return the data back to the Step Function
#     event["inferences"] = inferences.decode('utf-8')
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
#
# Finally, we need to filter low-confidence inferences. Define a threshold between 1.00 and 0.000 for your model: what is reasonble for you? If the model predicts at `.70` for it's highest confidence label, do we want to pass that inference along to downstream systems? Make one last Lambda function and tee up the same permissions:
#
# ```python
# import json
#
#
# THRESHOLD = .93
#
#
# def lambda_handler(event, context):
#
#     # Grab the inferences from the event
#     inferences = ## TODO: fill in
#
#     # Check if any values in our inferences are above THRESHOLD
#     meets_threshold = ## TODO: fill in
#
#     # If our threshold is met, pass our data back out of the
#     # Step Function, else, end the Step Function with an error
#     if meets_threshold:
#         pass
#     else:
#         raise("THRESHOLD_CONFIDENCE_NOT_MET")
#
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
# Once you have tested the lambda functions, save the code for each lambda function in a python script called 'lambda.py'.
#
# With your lambdas in place, you can use the Step Functions visual editor to construct a workflow that chains them together. In the Step Functions console you'll have the option to author a Standard step function *Visually*.
#
# When the visual editor opens, you'll have many options to add transitions in your workflow. We're going to keep it simple and have just one: to invoke Lambda functions. Add three of them chained together. For each one, you'll be able to select the Lambda functions you just created in the proper order, filter inputs and outputs, and give them descriptive names.
#
# Make sure that you:
#
# 1. Are properly filtering the inputs and outputs of your invokations (e.g. `$.body`)
# 2. Take care to remove the error handling from the last function - it's supposed to "fail loudly" for your operations colleagues!
#
# Take a screenshot of your working step function in action and export the step function as JSON for your submission package.

# %% [markdown]
# Great! Now you can use the files in `./test` as test files for our workflow. Depending on our threshold, our workflow should reliably pass predictions about images from `./test` on to downstream systems, while erroring out for inferences below our confidence threshold!
#
# ### Testing and Evaluation
#
# Do several step function invokations using data from the `./test` folder. This process should give you confidence that the workflow both *succeeds* AND *fails* as expected. In addition, SageMaker Model Monitor will generate recordings of your data and inferences which we can visualize.
#
# Here's a function that can help you generate test inputs for your invokations:

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]

# %%
# !pip install jsonschema==4.17.3
# Out:
# Collecting jsonschema==4.17.3
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema==4.17.3) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema==4.17.3) (0.19.3)
# Installing collected packages: jsonschema
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.18.4
#     Uninstalling jsonschema-4.18.4:
#       Successfully uninstalled jsonschema-4.18.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sparkmagic 0.20.5 requires nest-asyncio==1.5.5, but you have nest-asyncio 1.5.6 which is incompatible.
# sparkmagic 0.20.5 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.0.3 which is incompatible.
# Successfully installed jsonschema-4.17.3

# %%
import random
import boto3
import json


def generate_test_case():
    # Setup s3 in boto3
    s3 = boto3.resource('s3')
    
    # Randomly pick from sfn or test folders in our bucket
    objects = s3.Bucket(bucket).objects.filter("test")
    
    # Grab any random object key from that folder!
    obj = random.choice([x.key for x in objects])
    
    return json.dumps({
        "image_data": "",
        "s3_bucket": bucket,
        "s3_key": obj
    })
generate_test_case()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 21
#      14     obj = random.choice([x.key for x in objects])
#      16     return json.dumps({
#      17         "image_data": "",
#      18         "s3_bucket": bucket,
#      19         "s3_key": obj
#      20     })
# ---> 21 generate_test_case()
#
# Cell In[56], line 11, in generate_test_case()
#       8 s3 = boto3.resource('s3')
#      10 # Randomly pick from sfn or test folders in our bucket
# ---> 11 objects = s3.Bucket(bucket).objects.filter("test")
#      13 # Grab any random object key from that folder!
#      14 obj = random.choice([x.key for x in objects])
#
# TypeError: CollectionFactory._load_documented_collection_methods.<locals>.filter() takes 1 positional argument but 2 were given

# %% [markdown]
# In the Step Function dashboard for your new function, you can create new executions and copy in the generated test cases. Do several executions so that you can generate data you can evaluate and visualize.
#
# Once you've done several executions, let's visualize the record of our inferences. Pull in the JSONLines data from your inferences like so:

# %%
from sagemaker.s3 import S3Downloader

# In S3 your data will be saved to a datetime-aware path
# Find a path related to a datetime you're interested in
data_path = "s3://vedrauxx/data_capture/image-classification-2023-09-01-17-32-58-596/AllTraffic/2023/09/01/21/58-20-118-ff6eaa1e-d8c3-40f1-9d50-709004b6cb35.jsonl"

S3Downloader.download(data_path, "captured_data")

# Feel free to repeat this multiple times and pull in more data
# Out:
# ['captured_data/58-20-118-ff6eaa1e-d8c3-40f1-9d50-709004b6cb35.jsonl']

# %% [markdown]
# The data are in JSONLines format, where multiple valid JSON objects are stacked on top of eachother in a single `jsonl` file. We'll import an open-source library, `jsonlines` that was purpose built for parsing this format.

# %%
# !pip install jsonlines
import jsonlines
# Out:
# Collecting jsonlines
#   Obtaining dependency information for jsonlines from https://files.pythonhosted.org/packages/f8/62/d9ba6323b9202dd2fe166beab8a86d29465c41a0288cbe229fac60c1ab8d/jsonlines-4.0.0-py3-none-any.whl.metadata
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonlines) (23.1.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0

# %% [markdown]
# Now we can extract the data from each of the source files:

# %%
import os

# List the file names we downloaded
file_handles = []
for root, subFolders, files in os.walk("./captured_data"):
    if files:
        file_handles += [root + '/' + file for file in files]

# Dump all the data into an array
json_data = []
for jsonl in file_handles:
    with jsonlines.open(jsonl) as f:
        json_data.append(f.read())

# %% [markdown]
# The data should now be a list of dictionaries, with significant nesting. We'll give you an example of some code that grabs data out of the objects and visualizes it:

# %%
# Define how we'll get our data
def simple_getter(obj):
    inferences = obj["captureData"]["endpointOutput"]["data"]
    timestamp = obj["eventMetadata"]["inferenceTime"]
    return json.loads(inferences), timestamp

simple_getter(json_data[0])
# Out:
# ([0.998445451259613, 0.001554543967358768], '2023-09-01T21:08:38Z')

# %% [markdown]
# Finally, here's an example of a visualization you can build with this data. In this last part, you will take some time and build your own - the captured data has the input images, the resulting inferences, and the timestamps.

# %%
# Populate the data for the x and y axis
x = []
y = []
for obj in json_data:
    inference, timestamp = simple_getter(obj)
    
    y.append(max(inference))
    x.append(timestamp)

# Todo: here is an visualization example, take some time to build another visual that helps monitor the result
# Plot the data
plt.scatter(x, y, c=['r' if k<.94 else 'b' for k in y ])
plt.axhline(y=0.94, color='g', linestyle='--')
plt.ylim(bottom=.88)

# Add labels
plt.ylabel("Confidence")
plt.suptitle("Observed Recent Inferences", size=14)
plt.title("Pictured with confidence threshold for production use", size=10)

# Give it some pizzaz!
plt.style.use("Solarize_Light2")
plt.gcf().autofmt_xdate()

# %% [markdown]
# ### Todo: build your own visualization

# %% [markdown]
# ### Congratulations!
#
# You've reached the end of the project. In this project you created an event-drivent ML workflow that can be incorporated into the Scones Unlimited production architecture. You used the SageMaker Estimator API to deploy your SageMaker Model and Endpoint, and you used AWS Lambda and Step Functions to orchestrate your ML workflow. Using SageMaker Model Monitor, you instrumented and observed your Endpoint, and at the end of the project you built a visualization to help stakeholders understand the performance of the Endpoint over time. If you're up for it, you can even go further with these stretch goals:
#
# * Extend your workflow to incorporate more classes: the CIFAR dataset includes other vehicles that Scones Unlimited can identify with this model.
# * Modify your event driven workflow: can you rewrite your Lambda functions so that the workflow can process multiple image inputs in parallel? Can the Step Function "fan out" to accomodate this new workflow?
# * Consider the test data generator we provided for you. Can we use it to create a "dummy data" generator, to simulate a continuous stream of input data? Or a big paralell load of data?
# * What if we want to get notified every time our step function errors out? Can we use the Step Functions visual editor in conjunction with a service like SNS to accomplish this? Try it out!
